# %%
 def convert (s):

  new = ""
  for x in s:
    new += x

    return new

  #driver code
  s = ['g','e','e','k','s','f','o','r','g','e','e','k','s']
  print(convert (s))

# %%
  def Huruf (s) :
    abjad = ""
    for x in s :
      abjad += x

    return abjad

  # driver code
  s = ['p','r','o','g','r','a','m','m','i','n','g']
  print(Huruf (s))
# Out:
# programming
